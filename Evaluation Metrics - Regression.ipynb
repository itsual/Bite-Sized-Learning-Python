# %%
from IPython.display import Image
from IPython.core.display import HTML 
#Image(url= "https://miro.medium.com/proxy/0*zX9jlpZ8k0CuEpFE.jpg")

# %% [markdown]
# # Mean Squared Error (MSE)

# %%
PATH = "C:/Users/arock.000/Downloads/"
Image(filename = PATH + "MSE.jpg", width=600, height=400)

# %%
from sklearn.metrics import mean_squared_error 
  
# Given values 
Y_true = [1,1,2,3,5]  # Y_true = Y (original values) 
  
# calculated values 
Y_pred = [0.8,1.2,1.9,3.9,4.4]  # Y_pred = Y' 
  
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(Y_true,Y_pred)
# Out:
# 0.2519999999999999

# %% [markdown]
# [Scikit-Learn ](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)

# %% [markdown]
# # Mean Absolute Error (MAE)

# %%
PATH = "C:/Users/arock.000/Downloads/"
Image(filename = PATH + "MAE.jpg", width=600, height=400)

# %%
from sklearn.metrics import mean_absolute_error

# Given values
y_true = [4, 0.5, -2, 9]

# calculated values 
y_pred = [5.5, 0.0, -2, 8]

# Calculation of Mean Absolute Error (MAE)
mean_absolute_error(y_true, y_pred)
# Out:
# 0.75

# %% [markdown]
# [Scikit-Learn ](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html#sklearn.metrics.mean_absolute_error)

# %% [markdown]
# # Root Mean Squared Error (RMSE)

# %%
PATH = "C:/Users/arock.000/Downloads/"
Image(filename = PATH + "RMSE.png", width=600, height=400)

# %%
from math import sqrt

# Given values 
Y_true = [1,1,2,3,5]  # Y_true = Y (original values) 
  
# calculated values 
Y_pred = [0.8,1.2,1.9,3.9,4.4]  # Y_pred = Y' 
  
# Calculation of Root Mean Squared Error (RMSE) 
sqrt(mean_squared_error(Y_true, Y_pred))
# Out:
# 0.5019960159204452

# %% [markdown]
# [Stackoverflow](https://stackoverflow.com/questions/17197492/is-there-a-library-function-for-root-mean-square-error-rmse-in-python)

# %% [markdown]
# # R² Error

# %%
PATH = "C:/Users/arock.000/Downloads/"
Image(filename = PATH + "R2.png", width=600, height=400)

# %%
from sklearn.metrics import r2_score

# Given values 
y_true = [3, -0.5, 2, 7]

# calculated values
y_pred = [2.5, 0.0, 2, 8]

# Calculation of R Square (r2_score) 
r2_score(y_true, y_pred)
# Out:
# 0.9486081370449679

# %% [markdown]
# [Scikit-Learn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score)

# %% [markdown]
# # Adjusted R²

# %%
PATH = "C:/Users/arock.000/Downloads/"
Image(filename = PATH + "Adjusted R2.png", width=600, height=400)

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
import matplotlib.pyplot as plt



diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target
X2 = sm.add_constant(X) 
est = sm.OLS(y, X2)
est2 = est.fit()
print("summary()\n",est2.summary())
print("pvalues\n",est2.pvalues)
print("tvalues\n",est2.tvalues)
print("rsquared\n",est2.rsquared)
print("rsquared_adj\n",est2.rsquared_adj)

#All the attributes 
for attr in dir(est2):
    if not attr.startswith('_'):
        print(attr)

predictions = est2.predict(X2)

print(est2.predict(X2[:3,:]))

from sklearn.metrics import r2_score
print("r2_score",r2_score(y,predictions))
# Out:
# summary()
#                              OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     46.27
# Date:                Tue, 13 Oct 2020   Prob (F-statistic):           3.83e-62
# Time:                        11:06:13   Log-Likelihood:                -2386.0
# No. Observations:                 442   AIC:                             4794.
# Df Residuals:                     431   BIC:                             4839.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        152.1335      2.576     59.061      0.000     147.071     157.196
# ...

# %% [markdown]
# [Analytics Vidhya](https://discuss.analyticsvidhya.com/t/getting-p-value-r-squared-and-adjusted-r-squared-value-in-python/31528/6)
